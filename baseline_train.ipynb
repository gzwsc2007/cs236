# %%
import torch
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import tqdm
import numpy as np
import wandb
import time

import utils

import os
import sys
module_paths =  [
    os.path.abspath(os.path.join('ronin/source'))  # RoNIN
]
for module_path in module_paths:
    if module_path not in sys.path:
        sys.path.append(module_path)

import data_glob_speed
import data_ridi
import cnn_vae_model

# WANDB API Key: eefeec3d5632912a6bb9112f48d2dde3ca6e0658
wandb.login()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# wandb: Currently logged in as: ansonw. Use `wandb login --relogin` to force relogin
# cuda

# %% [markdown]
# # Load RONIN dataset

# %%
DATA_ROOT_DIR = 'datasets'
with open('datasets/self_sup_ronin_train_list.txt') as f:
    ronin_data_list = [s.strip().split(',' or ' ')[0] for s in f.readlines() if len(s) > 0 and s[0] != '#']

# Each item in the dataset is a (feature, target, seq_id, frame_id) tuple.
# Each feature is a 6x200 array. Rows 0-2 are gyro, and rows 3-5 are accel (non gravity subtracted).
# Both gyro and accels are in a gravity-aligned world frame (arbitrary yaw, but consistent throughout
# the 200 frames)
ronin_train_dataset = data_glob_speed.StridedSequenceDataset(data_glob_speed.GlobSpeedSequence,
                                                             DATA_ROOT_DIR,
                                                             ronin_data_list,
                                                             cache_path='datasets/cache')

batch_size = 128
train_loader = DataLoader(ronin_train_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Define model

# %%
latent_dim = 64
first_chan_size = 64
last_chan_size = 512
encoder_fc_dim = 256
encoder = cnn_vae_model.ResNetEncoder(feature_dim=6,
                                 latent_dim=latent_dim,
                                 first_channel_size=first_chan_size,
                                 last_channel_size=last_chan_size,
                                 fc_dim=encoder_fc_dim).to(device)

vel_fc_dims = [512]
dropout = 0.5
lr = 1e-4
vel_model = cnn_vae_model.VelocityRegressor(encoder, vel_fc_dims, num_outputs=2, dropout=dropout).to(device)

# %% [markdown]
# # Supervised training

# %%
def get_model_name():
    name = "baseline_lr_{}_FC".format(lr)
    for fc_dim in vel_fc_dims:
        name += "_{}".format(fc_dim)
    return name

# WANDB setup
wandb_run = wandb.init(
    # Set the project where this run will be logged
    project="Baseline-RONIN-dataset-supervised",
    # Track hyperparameters and run metadata
    config={
        "vel_fc_dims": vel_fc_dims,
        "dropout": dropout,
        "lr": lr,
        "latent_dim": latent_dim,
        "encoder_first_chan_size": first_chan_size,
        "encoder_last_chan_size": last_chan_size,
        "encoder_fc_dim": encoder_fc_dim,
        "batch_size": batch_size
})

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(vel_model.parameters(), lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.1, patience=10, verbose=True, eps=1e-12)

if 'start_epoch' not in locals():
    start_epoch = 0

max_epochs = 5000
best_loss = np.inf
train_losses_all = []
for epoch in range(start_epoch, max_epochs):
    start_t = time.time()
    vel_model.train()
    train_outs, train_targets = [], []
    for batch_id, (feat, targ, _, _) in enumerate(train_loader):
        feat, targ = feat.to(device), targ.to(device)
        optimizer.zero_grad()
        pred = vel_model(feat)
        train_outs.append(pred.cpu().detach().numpy())
        train_targets.append(targ.cpu().detach().numpy())
        loss = criterion(pred, targ)
        loss = torch.mean(loss)
        loss.backward()
        optimizer.step()
    train_outs = np.concatenate(train_outs, axis=0)
    train_targets = np.concatenate(train_targets, axis=0)
    train_losses = np.average((train_outs - train_targets) ** 2, axis=0)

    end_t = time.time()
    print('-------------------------')
    print('Epoch {}, time usage: {:.3f}s, average loss: {}/{:.6f}'.format(
        epoch, end_t - start_t, train_losses, np.average(train_losses)))
    avg_loss = np.average(train_losses)
    train_losses_all.append(avg_loss)

    wandb_run.log({"vel_x_loss": train_losses[0],
                   "vel_y_loss": train_losses[1],
                   "avg_loss": avg_loss})

    if avg_loss < best_loss:
        best_loss = avg_loss
        utils.save_states(get_model_name(), epoch, vel_model, optimizer)
# Out:
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/anson/cs236/project/wandb/run-20231201_232817-srrtzmx6</code>
# Syncing run <strong><a href='https://wandb.ai/ansonw/Baseline-RONIN-dataset-supervised/runs/srrtzmx6' target="_blank">still-microwave-2</a></strong> to <a href='https://wandb.ai/ansonw/Baseline-RONIN-dataset-supervised' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ansonw/Baseline-RONIN-dataset-supervised' target="_blank">https://wandb.ai/ansonw/Baseline-RONIN-dataset-supervised</a>
#  View run at <a href='https://wandb.ai/ansonw/Baseline-RONIN-dataset-supervised/runs/srrtzmx6' target="_blank">https://wandb.ai/ansonw/Baseline-RONIN-dataset-supervised/runs/srrtzmx6</a>
# -------------------------
# Epoch 0, time usage: 106.973s, average loss: [0.04673219 0.04989984]/0.048316
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00000.pt
# -------------------------
# Epoch 1, time usage: 107.221s, average loss: [0.02204478 0.02442742]/0.023236
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00001.pt
# -------------------------
# Epoch 2, time usage: 107.683s, average loss: [0.01658193 0.01861861]/0.017600
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00002.pt
# -------------------------
# Epoch 3, time usage: 107.495s, average loss: [0.01386032 0.01561496]/0.014738
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00003.pt
# -------------------------
# Epoch 4, time usage: 107.766s, average loss: [0.01213281 0.0136878 ]/0.012910
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00004.pt
# -------------------------
# Epoch 5, time usage: 107.827s, average loss: [0.01094766 0.01230246]/0.011625
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00005.pt
# -------------------------
# Epoch 6, time usage: 106.759s, average loss: [0.01021206 0.01136843]/0.010790
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00006.pt
# -------------------------
# Epoch 7, time usage: 108.033s, average loss: [0.00952519 0.01052103]/0.010023
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00007.pt
# -------------------------
# Epoch 8, time usage: 108.254s, average loss: [0.00899212 0.00998265]/0.009487
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00008.pt
# -------------------------
# Epoch 9, time usage: 108.038s, average loss: [0.00873126 0.00959467]/0.009163
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00009.pt
# -------------------------
# Epoch 10, time usage: 107.817s, average loss: [0.00824867 0.00925561]/0.008752
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00010.pt
# -------------------------
# Epoch 11, time usage: 107.967s, average loss: [0.00786594 0.00877985]/0.008323
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00011.pt
# -------------------------
# Epoch 12, time usage: 108.048s, average loss: [0.00768326 0.00847718]/0.008080
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00012.pt
# -------------------------
# Epoch 13, time usage: 108.181s, average loss: [0.00741838 0.00826795]/0.007843
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00013.pt
# -------------------------
# Epoch 14, time usage: 108.206s, average loss: [0.00729936 0.00813452]/0.007717
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00014.pt
# -------------------------
# Epoch 15, time usage: 108.147s, average loss: [0.00698783 0.0077925 ]/0.007390
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00015.pt
# -------------------------
# Epoch 16, time usage: 107.431s, average loss: [0.00703779 0.00771602]/0.007377
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00016.pt
# -------------------------
# Epoch 17, time usage: 108.662s, average loss: [0.0067648 0.0074788]/0.007122
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00017.pt
# -------------------------
# Epoch 18, time usage: 108.437s, average loss: [0.00671788 0.00740909]/0.007063
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00018.pt
# -------------------------
# Epoch 19, time usage: 108.447s, average loss: [0.00645505 0.00716419]/0.006810
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00019.pt
# -------------------------
# Epoch 20, time usage: 108.456s, average loss: [0.00649066 0.00717904]/0.006835
# -------------------------
# Epoch 21, time usage: 108.093s, average loss: [0.00633212 0.00710554]/0.006719
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00021.pt
# -------------------------
# Epoch 22, time usage: 108.352s, average loss: [0.00624041 0.00694344]/0.006592
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00022.pt
# -------------------------
# Epoch 23, time usage: 108.177s, average loss: [0.00613694 0.00681161]/0.006474
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00023.pt
# -------------------------
# Epoch 24, time usage: 108.089s, average loss: [0.0060466  0.00672051]/0.006384
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00024.pt
# -------------------------
# Epoch 25, time usage: 108.388s, average loss: [0.00594615 0.00662171]/0.006284
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00025.pt
# -------------------------
# Epoch 26, time usage: 108.134s, average loss: [0.0058903  0.00659073]/0.006241
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00026.pt
# -------------------------
# Epoch 27, time usage: 107.889s, average loss: [0.00588881 0.006683  ]/0.006286
# -------------------------
# Epoch 28, time usage: 107.747s, average loss: [0.00577193 0.00646371]/0.006118
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00028.pt
# -------------------------
# Epoch 29, time usage: 108.454s, average loss: [0.00573964 0.00644008]/0.006090
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00029.pt
# -------------------------
# Epoch 30, time usage: 107.987s, average loss: [0.00566075 0.00625424]/0.005957
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00030.pt
# -------------------------
# Epoch 31, time usage: 107.927s, average loss: [0.005644   0.00626951]/0.005957
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00031.pt
# -------------------------
# Epoch 32, time usage: 108.032s, average loss: [0.00560807 0.00617309]/0.005891
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00032.pt
# -------------------------
# Epoch 33, time usage: 108.452s, average loss: [0.00564254 0.00621092]/0.005927
# -------------------------
# Epoch 34, time usage: 107.616s, average loss: [0.00546414 0.0061214 ]/0.005793
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00034.pt
# -------------------------
# Epoch 35, time usage: 107.887s, average loss: [0.00544377 0.0061064 ]/0.005775
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00035.pt
# -------------------------
# Epoch 36, time usage: 107.979s, average loss: [0.00546191 0.00605638]/0.005759
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00036.pt
# -------------------------
# Epoch 37, time usage: 107.833s, average loss: [0.00537109 0.00598568]/0.005678
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00037.pt
# -------------------------
# Epoch 38, time usage: 107.643s, average loss: [0.005325   0.00599868]/0.005662
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00038.pt
# -------------------------
# Epoch 39, time usage: 107.285s, average loss: [0.00527757 0.00591148]/0.005595
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00039.pt
# -------------------------
# Epoch 40, time usage: 108.062s, average loss: [0.00528856 0.00591268]/0.005601
# -------------------------
# Epoch 41, time usage: 107.987s, average loss: [0.00522452 0.00580738]/0.005516
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00041.pt
# -------------------------
# Epoch 42, time usage: 107.865s, average loss: [0.00518104 0.00578147]/0.005481
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00042.pt
# -------------------------
# Epoch 43, time usage: 108.169s, average loss: [0.0052365  0.00579713]/0.005517
# -------------------------
# Epoch 44, time usage: 108.352s, average loss: [0.00509911 0.00570101]/0.005400
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00044.pt
# -------------------------
# Epoch 45, time usage: 108.065s, average loss: [0.00506448 0.0056616 ]/0.005363
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00045.pt
# -------------------------
# Epoch 46, time usage: 107.870s, average loss: [0.0050544  0.00563576]/0.005345
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00046.pt
# -------------------------
# Epoch 47, time usage: 108.440s, average loss: [0.00502189 0.00566481]/0.005343
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00047.pt
# -------------------------
# Epoch 48, time usage: 108.055s, average loss: [0.00498663 0.00558462]/0.005286
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00048.pt
# -------------------------
# Epoch 49, time usage: 108.256s, average loss: [0.00496229 0.00555002]/0.005256
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00049.pt
# -------------------------
# Epoch 50, time usage: 108.042s, average loss: [0.00501114 0.00556883]/0.005290
# -------------------------
# Epoch 51, time usage: 107.849s, average loss: [0.00494615 0.00555645]/0.005251
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00051.pt
# -------------------------
# Epoch 52, time usage: 107.798s, average loss: [0.00492399 0.00552259]/0.005223
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00052.pt
# -------------------------
# Epoch 53, time usage: 107.556s, average loss: [0.00491553 0.00551536]/0.005215
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00053.pt
# -------------------------
# Epoch 54, time usage: 107.832s, average loss: [0.00487592 0.00545479]/0.005165
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00054.pt
# -------------------------
# Epoch 55, time usage: 108.150s, average loss: [0.00486539 0.00546544]/0.005165
# -------------------------
# Epoch 56, time usage: 108.390s, average loss: [0.00484613 0.00541935]/0.005133
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00056.pt
# -------------------------
# Epoch 57, time usage: 108.726s, average loss: [0.00483993 0.00540745]/0.005124
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00057.pt
# -------------------------
# Epoch 58, time usage: 108.045s, average loss: [0.00480045 0.00539232]/0.005096
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00058.pt
# -------------------------
# Epoch 59, time usage: 107.939s, average loss: [0.00478695 0.00538068]/0.005084
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00059.pt
# -------------------------
# Epoch 60, time usage: 108.048s, average loss: [0.00477508 0.00538247]/0.005079
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00060.pt
# -------------------------
# Epoch 61, time usage: 108.005s, average loss: [0.00475921 0.00533807]/0.005049
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00061.pt
# -------------------------
# Epoch 62, time usage: 108.072s, average loss: [0.00473649 0.00532002]/0.005028
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00062.pt
# -------------------------
# Epoch 63, time usage: 108.194s, average loss: [0.00475096 0.00529664]/0.005024
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00063.pt
# -------------------------
# Epoch 64, time usage: 108.612s, average loss: [0.00469311 0.00529534]/0.004994
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00064.pt
# -------------------------
# Epoch 65, time usage: 108.525s, average loss: [0.00471231 0.00532178]/0.005017
# -------------------------
# Epoch 66, time usage: 108.330s, average loss: [0.00466848 0.00527126]/0.004970
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00066.pt
# -------------------------
# Epoch 67, time usage: 108.534s, average loss: [0.0046687  0.00525175]/0.004960
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00067.pt
# -------------------------
# Epoch 68, time usage: 108.412s, average loss: [0.00465826 0.00530143]/0.004980
# -------------------------
# Epoch 69, time usage: 108.057s, average loss: [0.00464439 0.00521863]/0.004932
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00069.pt
# -------------------------
# Epoch 70, time usage: 108.021s, average loss: [0.00462461 0.00520263]/0.004914
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00070.pt
# -------------------------
# Epoch 71, time usage: 107.982s, average loss: [0.00463195 0.00523532]/0.004934
# -------------------------
# Epoch 72, time usage: 108.454s, average loss: [0.0046094  0.00518116]/0.004895
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00072.pt
# -------------------------
# Epoch 73, time usage: 108.329s, average loss: [0.00460432 0.00518076]/0.004893
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00073.pt
# -------------------------
# Epoch 74, time usage: 107.999s, average loss: [0.00457408 0.00516058]/0.004867
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00074.pt
# -------------------------
# Epoch 75, time usage: 108.140s, average loss: [0.0045919  0.00514181]/0.004867
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00075.pt
# -------------------------
# Epoch 76, time usage: 108.093s, average loss: [0.00456119 0.00512746]/0.004844
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00076.pt
# -------------------------
# Epoch 77, time usage: 107.968s, average loss: [0.0045524  0.00512024]/0.004836
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00077.pt
# -------------------------
# Epoch 78, time usage: 107.920s, average loss: [0.00454513 0.00511252]/0.004829
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00078.pt
# -------------------------
# Epoch 79, time usage: 107.487s, average loss: [0.00452862 0.00509286]/0.004811
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00079.pt
# -------------------------
# Epoch 80, time usage: 108.069s, average loss: [0.00452624 0.00510042]/0.004813
# -------------------------
# Epoch 81, time usage: 108.326s, average loss: [0.00451097 0.00508688]/0.004799
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00081.pt
# -------------------------
# Epoch 82, time usage: 108.443s, average loss: [0.00451537 0.00508572]/0.004801
# -------------------------
# Epoch 83, time usage: 107.789s, average loss: [0.00448236 0.0050572 ]/0.004770
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00083.pt
# -------------------------
# Epoch 84, time usage: 107.936s, average loss: [0.00450154 0.00504756]/0.004775
# -------------------------
# Epoch 85, time usage: 107.965s, average loss: [0.00447744 0.00503452]/0.004756
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00085.pt
# -------------------------
# Epoch 86, time usage: 107.888s, average loss: [0.00446824 0.00505522]/0.004762
# -------------------------
# Epoch 87, time usage: 107.098s, average loss: [0.00447813 0.00504678]/0.004762
# -------------------------
# Epoch 88, time usage: 107.965s, average loss: [0.00445121 0.00504557]/0.004748
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00088.pt
# -------------------------
# Epoch 89, time usage: 107.444s, average loss: [0.00444498 0.00501903]/0.004732
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00089.pt
# -------------------------
# Epoch 90, time usage: 107.988s, average loss: [0.00444084 0.00501074]/0.004726
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00090.pt
# -------------------------
# Epoch 91, time usage: 107.720s, average loss: [0.00442209 0.00499592]/0.004709
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00091.pt
# -------------------------
# Epoch 92, time usage: 108.103s, average loss: [0.00443779 0.00497734]/0.004708
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00092.pt
# -------------------------
# Epoch 93, time usage: 107.862s, average loss: [0.00442465 0.00499435]/0.004710
# -------------------------
# Epoch 94, time usage: 108.184s, average loss: [0.00441404 0.00498286]/0.004698
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00094.pt
# -------------------------
# Epoch 95, time usage: 107.590s, average loss: [0.00442336 0.00499181]/0.004708
# -------------------------
# Epoch 96, time usage: 107.718s, average loss: [0.00441565 0.00495405]/0.004685
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00096.pt
# -------------------------
# Epoch 97, time usage: 107.671s, average loss: [0.00437386 0.00494503]/0.004659
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00097.pt
# -------------------------
# Epoch 98, time usage: 107.377s, average loss: [0.00437522 0.0049454 ]/0.004660
# -------------------------
# Epoch 99, time usage: 108.389s, average loss: [0.00439495 0.00505398]/0.004724
# -------------------------
# Epoch 100, time usage: 108.240s, average loss: [0.00438026 0.00492818]/0.004654
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00100.pt
# -------------------------
# Epoch 101, time usage: 107.814s, average loss: [0.00437327 0.00498449]/0.004679
# -------------------------
# Epoch 102, time usage: 107.712s, average loss: [0.00434724 0.00490281]/0.004625
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00102.pt
# -------------------------
# Epoch 103, time usage: 107.860s, average loss: [0.00436427 0.00492775]/0.004646
# -------------------------
# Epoch 104, time usage: 108.073s, average loss: [0.00434177 0.0048914 ]/0.004617
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00104.pt
# -------------------------
# Epoch 105, time usage: 107.615s, average loss: [0.00433884 0.00489691]/0.004618
# -------------------------
# Epoch 106, time usage: 108.350s, average loss: [0.00431937 0.00486706]/0.004593
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00106.pt
# -------------------------
# Epoch 107, time usage: 107.911s, average loss: [0.00430405 0.00486451]/0.004584
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00107.pt
# -------------------------
# Epoch 108, time usage: 108.293s, average loss: [0.0043162  0.00487442]/0.004595
# -------------------------
# Epoch 109, time usage: 108.290s, average loss: [0.00429889 0.00484916]/0.004574
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00109.pt
# -------------------------
# Epoch 110, time usage: 107.829s, average loss: [0.00429615 0.00484289]/0.004570
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00110.pt
# -------------------------
# Epoch 111, time usage: 107.763s, average loss: [0.00428865 0.00484237]/0.004566
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00111.pt
# -------------------------
# Epoch 112, time usage: 107.802s, average loss: [0.00428631 0.00484539]/0.004566
# -------------------------
# Epoch 113, time usage: 107.917s, average loss: [0.00428625 0.00483547]/0.004561
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00113.pt
# -------------------------
# Epoch 114, time usage: 108.249s, average loss: [0.00428491 0.00483411]/0.004560
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00114.pt
# -------------------------
# Epoch 115, time usage: 108.090s, average loss: [0.00428626 0.00485504]/0.004571
# -------------------------
# Epoch 116, time usage: 108.012s, average loss: [0.00429763 0.00482651]/0.004562
# -------------------------
# Epoch 117, time usage: 108.203s, average loss: [0.00428118 0.00481839]/0.004550
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00117.pt
# -------------------------
# Epoch 118, time usage: 108.083s, average loss: [0.00425164 0.00481754]/0.004535
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00118.pt
# -------------------------
# Epoch 119, time usage: 107.361s, average loss: [0.00425132 0.00481992]/0.004536
# -------------------------
# Epoch 120, time usage: 107.648s, average loss: [0.0042541 0.0048115]/0.004533
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00120.pt
# -------------------------
# Epoch 121, time usage: 107.911s, average loss: [0.00425982 0.00479565]/0.004528
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00121.pt
# -------------------------
# Epoch 122, time usage: 108.083s, average loss: [0.00424871 0.0047916 ]/0.004520
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00122.pt
# -------------------------
# Epoch 123, time usage: 108.141s, average loss: [0.00425698 0.00481578]/0.004536
# -------------------------
# Epoch 124, time usage: 107.868s, average loss: [0.00425899 0.00477454]/0.004517
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00124.pt
# -------------------------
# Epoch 125, time usage: 107.660s, average loss: [0.00420719 0.00477359]/0.004490
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00125.pt
# -------------------------
# Epoch 126, time usage: 108.324s, average loss: [0.00422257 0.00476436]/0.004493
# -------------------------
# Epoch 127, time usage: 107.996s, average loss: [0.0042218  0.00476102]/0.004491
# -------------------------
# Epoch 128, time usage: 108.354s, average loss: [0.00421633 0.00477874]/0.004498
# -------------------------
# Epoch 129, time usage: 108.417s, average loss: [0.00421823 0.0047911 ]/0.004505
# -------------------------
# Epoch 130, time usage: 108.433s, average loss: [0.00420858 0.00476905]/0.004489
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00130.pt
# -------------------------
# Epoch 131, time usage: 108.439s, average loss: [0.00419771 0.0047505 ]/0.004474
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00131.pt
# -------------------------
# Epoch 132, time usage: 108.494s, average loss: [0.00421974 0.00476407]/0.004492
# -------------------------
# Epoch 133, time usage: 107.900s, average loss: [0.00420532 0.00474436]/0.004475
# -------------------------
# Epoch 134, time usage: 108.370s, average loss: [0.00420038 0.00472582]/0.004463
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00134.pt
# -------------------------
# Epoch 135, time usage: 107.906s, average loss: [0.0041964 0.0047468]/0.004472
# -------------------------
# Epoch 136, time usage: 107.644s, average loss: [0.00418675 0.00472318]/0.004455
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00136.pt
# -------------------------
# Epoch 137, time usage: 107.892s, average loss: [0.0041915 0.0047265]/0.004459
# -------------------------
# Epoch 138, time usage: 107.668s, average loss: [0.00417119 0.00473014]/0.004451
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00138.pt
# -------------------------
# Epoch 139, time usage: 107.888s, average loss: [0.00416789 0.00471398]/0.004441
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00139.pt
# -------------------------
# Epoch 140, time usage: 107.453s, average loss: [0.00418611 0.00471192]/0.004449
# -------------------------
# Epoch 141, time usage: 108.155s, average loss: [0.00419524 0.00471554]/0.004455
# -------------------------
# Epoch 142, time usage: 107.834s, average loss: [0.00417485 0.00472866]/0.004452
# -------------------------
# Epoch 143, time usage: 107.843s, average loss: [0.00418781 0.00472551]/0.004457
# -------------------------
# Epoch 144, time usage: 107.793s, average loss: [0.00415746 0.00470088]/0.004429
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00144.pt
# -------------------------
# Epoch 145, time usage: 107.797s, average loss: [0.0041589  0.00471035]/0.004435
# -------------------------
# Epoch 146, time usage: 107.632s, average loss: [0.00417957 0.00470508]/0.004442
# -------------------------
# Epoch 147, time usage: 107.973s, average loss: [0.00416141 0.00470897]/0.004435
# -------------------------
# Epoch 148, time usage: 108.372s, average loss: [0.00415299 0.0046853 ]/0.004419
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00148.pt
# -------------------------
# Epoch 149, time usage: 107.387s, average loss: [0.00414062 0.00468405]/0.004412
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00149.pt
# -------------------------
# Epoch 150, time usage: 107.981s, average loss: [0.00415992 0.00469376]/0.004427
# -------------------------
# Epoch 151, time usage: 107.936s, average loss: [0.00415017 0.00468585]/0.004418
# -------------------------
# Epoch 152, time usage: 108.016s, average loss: [0.00414461 0.00466813]/0.004406
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00152.pt
# -------------------------
# Epoch 153, time usage: 107.923s, average loss: [0.00413899 0.00468997]/0.004414
# -------------------------
# Epoch 154, time usage: 108.336s, average loss: [0.00413327 0.00466394]/0.004399
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00154.pt
# -------------------------
# Epoch 155, time usage: 107.724s, average loss: [0.0041292  0.00469154]/0.004410
# -------------------------
# Epoch 156, time usage: 108.012s, average loss: [0.0041261  0.00465064]/0.004388
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00156.pt
# -------------------------
# Epoch 157, time usage: 107.587s, average loss: [0.00412155 0.00465614]/0.004389
# -------------------------
# Epoch 158, time usage: 107.984s, average loss: [0.00412369 0.00465517]/0.004389
# -------------------------
# Epoch 159, time usage: 108.198s, average loss: [0.00411359 0.00466052]/0.004387
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00159.pt
# -------------------------
# Epoch 160, time usage: 107.992s, average loss: [0.00412964 0.00464963]/0.004390
# -------------------------
# Epoch 161, time usage: 108.160s, average loss: [0.00411802 0.00467528]/0.004397
# -------------------------
# Epoch 162, time usage: 108.232s, average loss: [0.00412127 0.00464602]/0.004384
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00162.pt
# -------------------------
# Epoch 163, time usage: 108.100s, average loss: [0.00410391 0.00463534]/0.004370
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00163.pt
# -------------------------
# Epoch 164, time usage: 107.868s, average loss: [0.00410525 0.00463996]/0.004373
# -------------------------
# Epoch 165, time usage: 108.083s, average loss: [0.00409798 0.00463835]/0.004368
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00165.pt
# -------------------------
# Epoch 166, time usage: 107.917s, average loss: [0.00409459 0.00465132]/0.004373
# -------------------------
# Epoch 167, time usage: 108.070s, average loss: [0.00409066 0.00463276]/0.004362
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00167.pt
# -------------------------
# Epoch 168, time usage: 108.063s, average loss: [0.0041012  0.00463606]/0.004369
# -------------------------
# Epoch 169, time usage: 107.947s, average loss: [0.0040916  0.00462885]/0.004360
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00169.pt
# -------------------------
# Epoch 170, time usage: 107.645s, average loss: [0.00409281 0.00462234]/0.004358
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00170.pt
# -------------------------
# Epoch 171, time usage: 108.121s, average loss: [0.00408585 0.00463881]/0.004362
# -------------------------
# Epoch 172, time usage: 107.273s, average loss: [0.0040851  0.00463258]/0.004359
# -------------------------
# Epoch 173, time usage: 107.897s, average loss: [0.00407867 0.00462957]/0.004354
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00173.pt
# -------------------------
# Epoch 174, time usage: 108.026s, average loss: [0.00408581 0.00461968]/0.004353
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00174.pt
# -------------------------
# Epoch 175, time usage: 108.515s, average loss: [0.00407878 0.0046562 ]/0.004367
# -------------------------
# Epoch 176, time usage: 107.846s, average loss: [0.00407754 0.00461812]/0.004348
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00176.pt
# -------------------------
# Epoch 177, time usage: 108.199s, average loss: [0.00408102 0.00461537]/0.004348
# -------------------------
# Epoch 178, time usage: 108.048s, average loss: [0.00406536 0.00459616]/0.004331
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00178.pt
# -------------------------
# Epoch 179, time usage: 108.471s, average loss: [0.00406281 0.00460234]/0.004333
# -------------------------
# Epoch 180, time usage: 108.132s, average loss: [0.00407099 0.00459116]/0.004331
# -------------------------
# Epoch 181, time usage: 108.002s, average loss: [0.00406327 0.00458891]/0.004326
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00181.pt
# -------------------------
# Epoch 182, time usage: 108.044s, average loss: [0.00405398 0.00460569]/0.004330
# -------------------------
# Epoch 183, time usage: 108.008s, average loss: [0.0040655  0.00458999]/0.004328
# -------------------------
# Epoch 184, time usage: 108.052s, average loss: [0.00405736 0.00458787]/0.004323
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00184.pt
# -------------------------
# Epoch 185, time usage: 108.054s, average loss: [0.00405399 0.00457763]/0.004316
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00185.pt
# -------------------------
# Epoch 186, time usage: 108.350s, average loss: [0.00405314 0.00459074]/0.004322
# -------------------------
# Epoch 187, time usage: 108.420s, average loss: [0.00405836 0.00458533]/0.004322
# -------------------------
# Epoch 188, time usage: 108.075s, average loss: [0.00404794 0.00459398]/0.004321
# -------------------------
# Epoch 189, time usage: 108.168s, average loss: [0.0040432  0.00456523]/0.004304
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00189.pt
# -------------------------
# Epoch 190, time usage: 107.818s, average loss: [0.00404814 0.0045898 ]/0.004319
# -------------------------
# Epoch 191, time usage: 107.810s, average loss: [0.00404459 0.00459274]/0.004319
# -------------------------
# Epoch 192, time usage: 108.070s, average loss: [0.00404164 0.00459252]/0.004317
# -------------------------
# Epoch 193, time usage: 108.241s, average loss: [0.00403747 0.00457496]/0.004306
# -------------------------
# Epoch 194, time usage: 108.098s, average loss: [0.00403891 0.00455558]/0.004297
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00194.pt
# -------------------------
# Epoch 195, time usage: 107.660s, average loss: [0.00402984 0.00456648]/0.004298
# -------------------------
# Epoch 196, time usage: 108.212s, average loss: [0.00403399 0.00455701]/0.004296
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00196.pt
# -------------------------
# Epoch 197, time usage: 108.356s, average loss: [0.00403625 0.00457068]/0.004303
# -------------------------
# Epoch 198, time usage: 108.389s, average loss: [0.00403791 0.0045762 ]/0.004307
# -------------------------
# Epoch 199, time usage: 107.872s, average loss: [0.00403114 0.00457013]/0.004301
# -------------------------
# Epoch 200, time usage: 108.356s, average loss: [0.00402058 0.00458027]/0.004300
# -------------------------
# Epoch 201, time usage: 107.823s, average loss: [0.00402225 0.00455671]/0.004289
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00201.pt
# -------------------------
# Epoch 202, time usage: 107.768s, average loss: [0.00405538 0.00456408]/0.004310
# -------------------------
# Epoch 203, time usage: 107.888s, average loss: [0.00401853 0.00455458]/0.004287
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00203.pt
# -------------------------
# Epoch 204, time usage: 108.088s, average loss: [0.00403482 0.00455051]/0.004293
# -------------------------
# Epoch 205, time usage: 107.702s, average loss: [0.00400951 0.00455747]/0.004283
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00205.pt
# -------------------------
# Epoch 206, time usage: 108.026s, average loss: [0.00401509 0.00454579]/0.004280
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00206.pt
# -------------------------
# Epoch 207, time usage: 107.987s, average loss: [0.00400986 0.00453055]/0.004270
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00207.pt
# -------------------------
# Epoch 208, time usage: 108.091s, average loss: [0.0040238  0.00458096]/0.004302
# -------------------------
# Epoch 209, time usage: 108.254s, average loss: [0.00402481 0.00453466]/0.004280
# -------------------------
# Epoch 210, time usage: 108.568s, average loss: [0.00401648 0.00453159]/0.004274
# -------------------------
# Epoch 211, time usage: 108.266s, average loss: [0.00403235 0.00455644]/0.004294
# -------------------------
# Epoch 212, time usage: 108.004s, average loss: [0.00401368 0.00453795]/0.004276
# -------------------------
# Epoch 213, time usage: 107.626s, average loss: [0.0040037  0.00454869]/0.004276
# -------------------------
# Epoch 214, time usage: 108.056s, average loss: [0.00400731 0.00454444]/0.004276
# -------------------------
# Epoch 215, time usage: 108.345s, average loss: [0.00401438 0.00453803]/0.004276
# -------------------------
# Epoch 216, time usage: 108.363s, average loss: [0.00404248 0.00465908]/0.004351
# -------------------------
# Epoch 217, time usage: 108.187s, average loss: [0.00397134 0.00450781]/0.004240
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00217.pt
# -------------------------
# Epoch 218, time usage: 108.182s, average loss: [0.00399081 0.00453171]/0.004261
# -------------------------
# Epoch 219, time usage: 108.222s, average loss: [0.00397524 0.0045147 ]/0.004245
# -------------------------
# Epoch 220, time usage: 108.119s, average loss: [0.00401645 0.00453637]/0.004276
# -------------------------
# Epoch 221, time usage: 108.032s, average loss: [0.00399376 0.00453631]/0.004265
# -------------------------
# Epoch 222, time usage: 107.354s, average loss: [0.00399188 0.00452655]/0.004259
# -------------------------
# Epoch 223, time usage: 108.095s, average loss: [0.003995   0.00451548]/0.004255
# -------------------------
# Epoch 224, time usage: 108.027s, average loss: [0.00399609 0.00452546]/0.004261
# -------------------------
# Epoch 225, time usage: 107.892s, average loss: [0.00400254 0.00454085]/0.004272
# -------------------------
# Epoch 226, time usage: 107.372s, average loss: [0.00399394 0.00452127]/0.004258
# -------------------------
# Epoch 227, time usage: 107.958s, average loss: [0.00397717 0.00451891]/0.004248
# -------------------------
# Epoch 228, time usage: 107.805s, average loss: [0.00398087 0.00451655]/0.004249
# -------------------------
# Epoch 229, time usage: 108.182s, average loss: [0.0039778  0.00449697]/0.004237
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00229.pt
# -------------------------
# Epoch 230, time usage: 108.237s, average loss: [0.0039816  0.00451484]/0.004248
# -------------------------
# Epoch 231, time usage: 108.141s, average loss: [0.00395967 0.0045018 ]/0.004231
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00231.pt
# -------------------------
# Epoch 232, time usage: 108.124s, average loss: [0.00400287 0.00452656]/0.004265
# -------------------------
# Epoch 233, time usage: 108.233s, average loss: [0.0039759  0.00449383]/0.004235
# -------------------------
# Epoch 234, time usage: 107.169s, average loss: [0.00397248 0.00450476]/0.004239
# -------------------------
# Epoch 235, time usage: 107.986s, average loss: [0.00396898 0.00449928]/0.004234
# -------------------------
# Epoch 236, time usage: 108.296s, average loss: [0.00398596 0.00449819]/0.004242
# -------------------------
# Epoch 237, time usage: 108.355s, average loss: [0.00397463 0.00451084]/0.004243
# -------------------------
# Epoch 238, time usage: 108.355s, average loss: [0.00398553 0.00452443]/0.004255
# -------------------------
# Epoch 239, time usage: 107.433s, average loss: [0.00396796 0.00449064]/0.004229
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00239.pt
# -------------------------
# Epoch 240, time usage: 107.994s, average loss: [0.00396991 0.00448991]/0.004230
# -------------------------
# Epoch 241, time usage: 107.595s, average loss: [0.00395506 0.00450237]/0.004229
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00241.pt
# -------------------------
# Epoch 242, time usage: 108.101s, average loss: [0.00397524 0.00449539]/0.004235
# -------------------------
# Epoch 243, time usage: 107.799s, average loss: [0.00395937 0.00448438]/0.004222
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00243.pt
# -------------------------
# Epoch 244, time usage: 107.857s, average loss: [0.00397094 0.00449421]/0.004233
# -------------------------
# Epoch 245, time usage: 108.176s, average loss: [0.00394116 0.00448696]/0.004214
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00245.pt
# -------------------------
# Epoch 246, time usage: 108.037s, average loss: [0.00396214 0.00449721]/0.004230
# -------------------------
# Epoch 247, time usage: 108.066s, average loss: [0.00394083 0.00447437]/0.004208
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00247.pt
# -------------------------
# Epoch 248, time usage: 107.963s, average loss: [0.0039791  0.00449711]/0.004238
# -------------------------
# Epoch 249, time usage: 108.185s, average loss: [0.00393787 0.00447262]/0.004205
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00249.pt
# -------------------------
# Epoch 250, time usage: 108.065s, average loss: [0.00395098 0.00447635]/0.004214
# -------------------------
# Epoch 251, time usage: 108.361s, average loss: [0.00395583 0.00448586]/0.004221
# -------------------------
# Epoch 252, time usage: 108.484s, average loss: [0.00395182 0.00445938]/0.004206
# -------------------------
# Epoch 253, time usage: 108.292s, average loss: [0.00393053 0.00445662]/0.004194
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00253.pt
# -------------------------
# Epoch 254, time usage: 108.438s, average loss: [0.00394891 0.00447482]/0.004212
# -------------------------
# Epoch 255, time usage: 108.422s, average loss: [0.00395255 0.00447639]/0.004214
# -------------------------
# Epoch 256, time usage: 107.996s, average loss: [0.00393994 0.004475  ]/0.004207
# -------------------------
# Epoch 257, time usage: 108.165s, average loss: [0.00394012 0.00447869]/0.004209
# -------------------------
# Epoch 258, time usage: 107.890s, average loss: [0.00394374 0.00447545]/0.004210
# -------------------------
# Epoch 259, time usage: 108.197s, average loss: [0.0039452  0.00445594]/0.004201
# -------------------------
# Epoch 260, time usage: 108.450s, average loss: [0.00395226 0.00446779]/0.004210
# -------------------------
# Epoch 261, time usage: 108.218s, average loss: [0.00394211 0.0044803 ]/0.004211
# -------------------------
# Epoch 262, time usage: 108.479s, average loss: [0.00398559 0.0045115 ]/0.004249
# -------------------------
# Epoch 263, time usage: 108.044s, average loss: [0.00394605 0.00448018]/0.004213
# -------------------------
# Epoch 264, time usage: 108.166s, average loss: [0.00393731 0.00446115]/0.004199
# -------------------------
# Epoch 265, time usage: 108.249s, average loss: [0.00392319 0.00445206]/0.004188
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00265.pt
# -------------------------
# Epoch 266, time usage: 108.374s, average loss: [0.0039343  0.00444383]/0.004189
# -------------------------
# Epoch 267, time usage: 108.236s, average loss: [0.00393912 0.00444743]/0.004193
# -------------------------
# Epoch 268, time usage: 108.225s, average loss: [0.0039394  0.00447554]/0.004207
# -------------------------
# Epoch 269, time usage: 108.227s, average loss: [0.00398265 0.0044799 ]/0.004231
# -------------------------
# Epoch 270, time usage: 107.762s, average loss: [0.00399782 0.00452474]/0.004261
# -------------------------
# Epoch 271, time usage: 107.988s, average loss: [0.0039374  0.00446333]/0.004200
# -------------------------
# Epoch 272, time usage: 108.091s, average loss: [0.00396087 0.00447757]/0.004219
# -------------------------
# Epoch 273, time usage: 108.113s, average loss: [0.00393773 0.0044708 ]/0.004204
# -------------------------
# Epoch 274, time usage: 107.370s, average loss: [0.0039397  0.00445784]/0.004199
# -------------------------
# Epoch 275, time usage: 108.100s, average loss: [0.00393365 0.0044532 ]/0.004193
# -------------------------
# Epoch 276, time usage: 108.415s, average loss: [0.00392618 0.00445078]/0.004188
# -------------------------
# Epoch 277, time usage: 107.943s, average loss: [0.00392898 0.00445373]/0.004191
# -------------------------
# Epoch 278, time usage: 107.885s, average loss: [0.00391881 0.0044534 ]/0.004186
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00278.pt
# -------------------------
# Epoch 279, time usage: 107.886s, average loss: [0.00390818 0.00444752]/0.004178
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00279.pt
# -------------------------
# Epoch 280, time usage: 107.746s, average loss: [0.00391968 0.0044433 ]/0.004181
# -------------------------
# Epoch 281, time usage: 108.062s, average loss: [0.003931  0.0044562]/0.004194
# -------------------------
# Epoch 282, time usage: 107.887s, average loss: [0.00392118 0.00445093]/0.004186
# -------------------------
# Epoch 283, time usage: 107.818s, average loss: [0.00391886 0.00444273]/0.004181
# -------------------------
# Epoch 284, time usage: 107.731s, average loss: [0.00394788 0.00446392]/0.004206
# -------------------------
# Epoch 285, time usage: 108.132s, average loss: [0.00391106 0.004438  ]/0.004175
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00285.pt
# -------------------------
# Epoch 286, time usage: 107.965s, average loss: [0.00391837 0.00444744]/0.004183
# -------------------------
# Epoch 287, time usage: 108.004s, average loss: [0.0039127  0.00442406]/0.004168
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00287.pt
# -------------------------
# Epoch 288, time usage: 108.064s, average loss: [0.00390921 0.00443208]/0.004171
# -------------------------
# Epoch 289, time usage: 107.166s, average loss: [0.00390298 0.00443423]/0.004169
# -------------------------
# Epoch 290, time usage: 107.566s, average loss: [0.00391273 0.00443201]/0.004172
# -------------------------
# Epoch 291, time usage: 107.838s, average loss: [0.00391404 0.00442043]/0.004167
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00291.pt
# -------------------------
# Epoch 292, time usage: 108.165s, average loss: [0.00390623 0.00443527]/0.004171
# -------------------------
# Epoch 293, time usage: 108.308s, average loss: [0.00390385 0.00442191]/0.004163
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00293.pt
# -------------------------
# Epoch 294, time usage: 108.158s, average loss: [0.00390801 0.00442155]/0.004165
# -------------------------
# Epoch 295, time usage: 108.109s, average loss: [0.00389857 0.0044006 ]/0.004150
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00295.pt
# -------------------------
# Epoch 296, time usage: 108.055s, average loss: [0.00389723 0.00442498]/0.004161
# -------------------------
# Epoch 297, time usage: 107.975s, average loss: [0.00390227 0.00444227]/0.004172
# -------------------------
# Epoch 298, time usage: 108.438s, average loss: [0.00389378 0.00441252]/0.004153
# -------------------------
# Epoch 299, time usage: 108.296s, average loss: [0.00389114 0.00440655]/0.004149
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00299.pt
# -------------------------
# Epoch 300, time usage: 108.817s, average loss: [0.00388994 0.00440467]/0.004147
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00300.pt
# -------------------------
# Epoch 301, time usage: 107.935s, average loss: [0.00389959 0.00441133]/0.004155
# -------------------------
# Epoch 302, time usage: 107.905s, average loss: [0.00389627 0.00442256]/0.004159
# -------------------------
# Epoch 303, time usage: 107.581s, average loss: [0.00389798 0.0044115 ]/0.004155
# -------------------------
# Epoch 304, time usage: 108.158s, average loss: [0.00389545 0.00442785]/0.004162
# -------------------------
# Epoch 305, time usage: 108.024s, average loss: [0.00388944 0.00440205]/0.004146
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00305.pt
# -------------------------
# Epoch 306, time usage: 108.001s, average loss: [0.00390098 0.00441568]/0.004158
# -------------------------
# Epoch 307, time usage: 107.974s, average loss: [0.00388693 0.00441942]/0.004153
# -------------------------
# Epoch 308, time usage: 108.019s, average loss: [0.00389012 0.00440131]/0.004146
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00308.pt
# -------------------------
# Epoch 309, time usage: 108.051s, average loss: [0.0038889  0.00440243]/0.004146
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00309.pt
# -------------------------
# Epoch 310, time usage: 108.435s, average loss: [0.0038826  0.00440039]/0.004141
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00310.pt
# -------------------------
# Epoch 311, time usage: 108.148s, average loss: [0.00388412 0.00440907]/0.004147
# -------------------------
# Epoch 312, time usage: 108.087s, average loss: [0.00389257 0.00440678]/0.004150
# -------------------------
# Epoch 313, time usage: 108.002s, average loss: [0.00388921 0.00442053]/0.004155
# -------------------------
# Epoch 314, time usage: 108.158s, average loss: [0.00387471 0.00439881]/0.004137
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00314.pt
# -------------------------
# Epoch 315, time usage: 107.942s, average loss: [0.00388811 0.00440656]/0.004147
# -------------------------
# Epoch 316, time usage: 108.112s, average loss: [0.00387869 0.00438351]/0.004131
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00316.pt
# -------------------------
# Epoch 317, time usage: 107.950s, average loss: [0.00387499 0.00439473]/0.004135
# -------------------------
# Epoch 318, time usage: 108.160s, average loss: [0.00387754 0.00439858]/0.004138
# -------------------------
# Epoch 319, time usage: 108.309s, average loss: [0.00386852 0.00440309]/0.004136
# -------------------------
# Epoch 320, time usage: 108.321s, average loss: [0.00387169 0.00439319]/0.004132
# -------------------------
# Epoch 321, time usage: 108.244s, average loss: [0.003869  0.0043948]/0.004132
# -------------------------
# Epoch 322, time usage: 108.628s, average loss: [0.00387004 0.00438859]/0.004129
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00322.pt
# -------------------------
# Epoch 323, time usage: 107.613s, average loss: [0.00388678 0.00439352]/0.004140
# -------------------------
# Epoch 324, time usage: 108.479s, average loss: [0.00390578 0.00444041]/0.004173
# -------------------------
# Epoch 325, time usage: 108.327s, average loss: [0.00387996 0.00442296]/0.004151
# -------------------------
# Epoch 326, time usage: 108.161s, average loss: [0.00387632 0.00441748]/0.004147
# -------------------------
# Epoch 327, time usage: 108.310s, average loss: [0.00388456 0.00442594]/0.004155
# -------------------------
# Epoch 328, time usage: 108.159s, average loss: [0.00386834 0.00438674]/0.004128
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00328.pt
# -------------------------
# Epoch 329, time usage: 107.978s, average loss: [0.00386584 0.00441413]/0.004140
# -------------------------
# Epoch 330, time usage: 107.892s, average loss: [0.00387476 0.00440846]/0.004142
# -------------------------
# Epoch 331, time usage: 107.885s, average loss: [0.00388518 0.00440464]/0.004145
# -------------------------
# Epoch 332, time usage: 107.898s, average loss: [0.00387257 0.00437924]/0.004126
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00332.pt
# -------------------------
# Epoch 333, time usage: 108.061s, average loss: [0.00388345 0.00438193]/0.004133
# -------------------------
# Epoch 334, time usage: 108.386s, average loss: [0.0038641  0.00438333]/0.004124
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00334.pt
# -------------------------
# Epoch 335, time usage: 108.193s, average loss: [0.00387837 0.00438736]/0.004133
# -------------------------
# Epoch 336, time usage: 107.495s, average loss: [0.00386708 0.00439416]/0.004131
# -------------------------
# Epoch 337, time usage: 107.846s, average loss: [0.00385589 0.0043771 ]/0.004116
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00337.pt
# -------------------------
# Epoch 338, time usage: 108.162s, average loss: [0.00386297 0.00437433]/0.004119
# -------------------------
# Epoch 339, time usage: 107.720s, average loss: [0.00386825 0.00437086]/0.004120
# -------------------------
# Epoch 340, time usage: 107.794s, average loss: [0.00385511 0.00436229]/0.004109
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00340.pt
# -------------------------
# Epoch 341, time usage: 107.908s, average loss: [0.00386502 0.00437591]/0.004120
# -------------------------
# Epoch 342, time usage: 108.272s, average loss: [0.00385821 0.00438181]/0.004120
# -------------------------
# Epoch 343, time usage: 108.026s, average loss: [0.00386275 0.00436594]/0.004114
# -------------------------
# Epoch 344, time usage: 108.022s, average loss: [0.00385224 0.00437477]/0.004114
# -------------------------
# Epoch 345, time usage: 108.016s, average loss: [0.00386155 0.00437922]/0.004120
# -------------------------
# Epoch 346, time usage: 108.192s, average loss: [0.00385838 0.00438076]/0.004120
# -------------------------
# Epoch 347, time usage: 108.148s, average loss: [0.00384107 0.00437581]/0.004108
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00347.pt
# -------------------------
# Epoch 348, time usage: 107.965s, average loss: [0.00385227 0.00437266]/0.004112
# -------------------------
# Epoch 349, time usage: 108.160s, average loss: [0.00384891 0.00436508]/0.004107
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00349.pt
# -------------------------
# Epoch 350, time usage: 108.218s, average loss: [0.00385787 0.00437528]/0.004117
# -------------------------
# Epoch 351, time usage: 108.118s, average loss: [0.00384106 0.0043609 ]/0.004101
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00351.pt
# -------------------------
# Epoch 352, time usage: 107.718s, average loss: [0.00385823 0.00435811]/0.004108
# -------------------------
# Epoch 353, time usage: 108.041s, average loss: [0.00384615 0.00436599]/0.004106
# -------------------------
# Epoch 354, time usage: 107.121s, average loss: [0.00385584 0.00437663]/0.004116
# -------------------------
# Epoch 355, time usage: 108.061s, average loss: [0.00385685 0.0043586 ]/0.004108
# -------------------------
# Epoch 356, time usage: 108.030s, average loss: [0.00385389 0.00436779]/0.004111
# -------------------------
# Epoch 357, time usage: 107.805s, average loss: [0.00383124 0.0043724 ]/0.004102
# -------------------------
# Epoch 358, time usage: 107.825s, average loss: [0.00385695 0.00435523]/0.004106
# -------------------------
# Epoch 359, time usage: 108.221s, average loss: [0.00383875 0.00436161]/0.004100
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00359.pt
# -------------------------
# Epoch 360, time usage: 108.153s, average loss: [0.00384866 0.00437465]/0.004112
# -------------------------
# Epoch 361, time usage: 107.954s, average loss: [0.00385445 0.00437058]/0.004113
# -------------------------
# Epoch 362, time usage: 107.690s, average loss: [0.00383719 0.00435487]/0.004096
# Model saved to  checkpoints/baseline_lr_0.0001_FC_512/model-00362.pt
# -------------------------
# Epoch 363, time usage: 108.004s, average loss: [0.0038646  0.00441508]/0.004140
# -------------------------
# Epoch 364, time usage: 108.218s, average loss: [0.00386445 0.00437291]/0.004119
# -------------------------
# Epoch 365, time usage: 108.188s, average loss: [0.00385015 0.00435363]/0.004102
# -------------------------
# Epoch 366, time usage: 108.607s, average loss: [0.00385095 0.00437171]/0.004111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 38
#      36 train_outs, train_targets = [], []
#      37 for batch_id, (feat, targ, _, _) in enumerate(train_loader):
# ---> 38     feat, targ = feat.to(device), targ.to(device)
#      39     optimizer.zero_grad()
#      40     pred = vel_model(feat)
#
# KeyboardInterrupt:
# wandb: Network error (ReadTimeout), entering retry loop.
